# %% [markdown]
# # Capstone project on Udemy-Courses-dataset¶

# %%
# import libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## load the dataset

# %%
data=pd.read_csv("C:/Users/Admin/Documents/udemy courses.csv")
data
# Out:
#       course_id                                              title  is_paid  \
# 0        655608  Productivity and Time Management for the Overw...     True
# 1        591930  Become a SuperLearner® 2: Learn Speed Reading ...     True
# 2       1080376  Life Coaching Certificate Course (Beginner to ...     True
# 3       2108272      Time Management Mastery: Do More, Stress Less     True
# 4       1336872  Neuro-Linguistic Programming (NLP) Practitione...     True
# ...         ...                                                ...      ...
# 6146    2433278  Computer Basics - Windows 7/10 - Desktop IT Su...     True
# 6147    1638736              Understanding and Troubleshooting SIP     True
# 6148    1386242              Hands-on Penetration Testing Labs 1.0     True
# 6149    2773144                  The Complete C++ Developer Course     True
# 6150    3438306                Python NumPy For Absolute Beginners    False
#
# ...

# %%
data.dtypes
# Out:
# course_id                         int64
# title                            object
# is_paid                            bool
# instructors                      object
# published_title                  object
# num_subscribers                   int64
# avg_rating                      float64
# avg_rating_recent               float64
# rating                          float64
# num_reviews                       int64
# num_published_lectures            int64
# num_published_practice_tests      int64
# has_closed_caption                 bool
# created_at                       object
# instructional_level              object
# published_at                     object
# is_recently_published              bool
# last_update_date                 object
# content_info                     object
# category                         object
# dtype: object

# %%
data1=pd.read_csv("C:/Users/Admin/Documents/udemy courses.csv",parse_dates=['created_at'])
data1.dtypes
# Out:
# course_id                                     int64
# title                                        object
# is_paid                                        bool
# instructors                                  object
# published_title                              object
# num_subscribers                               int64
# avg_rating                                  float64
# avg_rating_recent                           float64
# rating                                      float64
# num_reviews                                   int64
# num_published_lectures                        int64
# num_published_practice_tests                  int64
# has_closed_caption                             bool
# created_at                      datetime64[ns, UTC]
# instructional_level                          object
# published_at                                 object
# is_recently_published                          bool
# last_update_date                             object
# ...

# %% [markdown]
# ## Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
print("Rows are :",data.shape[0],"Columns are:",data.shape[1])
# Out:
# Rows are : 6151 Columns are: 20

# %% [markdown]
# ## Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6151 entries, 0 to 6150
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   course_id                     6151 non-null   int64
#  1   title                         6151 non-null   object
#  2   is_paid                       6151 non-null   bool
#  3   instructors                   6151 non-null   object
#  4   published_title               6151 non-null   object
#  5   num_subscribers               6151 non-null   int64
#  6   avg_rating                    6151 non-null   float64
#  7   avg_rating_recent             6151 non-null   float64
#  8   rating                        6151 non-null   float64
#  9   num_reviews                   6151 non-null   int64
#  10  num_published_lectures        6151 non-null   int64
#  11  num_published_practice_tests  6151 non-null   int64
# ...

# %% [markdown]
# ## Check Null Values In The Dataset

# %%
print("Any missing values ?",data.isnull().values.any())
# Out:
# Any missing values ? False

# %%
data.isnull().sum()
# Out:
# course_id                       0
# title                           0
# is_paid                         0
# instructors                     0
# published_title                 0
# num_subscribers                 0
# avg_rating                      0
# avg_rating_recent               0
# rating                          0
# num_reviews                     0
# num_published_lectures          0
# num_published_practice_tests    0
# has_closed_caption              0
# created_at                      0
# instructional_level             0
# published_at                    0
# is_recently_published           0
# last_update_date                0
# content_info                    0
# category                        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## Check For Duplicate Data and Drop Them

# %%
data.duplicated().any(),data.duplicated().sum()
# Out:
# (False, 0)

# %% [markdown]
# ## Find Out Number of Courses Per category

# %%
data['category'].value_counts()
# Out:
# software                696
# marketting              611
# business                590
# finance                 535
# design                  530
# development             507
# personal_development    505
# photography             497
# health_fitness          473
# music                   413
# productivity            410
# lifestyle               384
# Name: category, dtype: int64

# %%
cat=data['category'].value_counts()

# %%
plt.xlabel('category')
plt.ylabel('Number of Courses')
plt.title('Number of Courses Per category')
plt.bar(cat.index,cat.values,width=0.8)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## For Which Levels, Udemy Courses Providing The Courses

# %%
data['instructional_level'].value_counts()
# Out:
# All Levels            3725
# Beginner Level        1872
# Intermediate Level     491
# Expert Level            63
# Name: instructional_level, dtype: int64

# %%
instructional_level=data['instructional_level'].value_counts()

# %%
plt.xlabel('Levels')
plt.ylabel('Number of Courses')
plt.title('Number of Courses Per Levels')
plt.bar(instructional_level.index,instructional_level.values,width=0.4)
plt.xticks(fontsize=8)
plt.show()

# %% [markdown]
# ## Count of paid and free courses

# %%
m=data['is_paid'].value_counts()
m
# Out:
# True     5217
# False     934
# Name: is_paid, dtype: int64

# %%
import seaborn as sns
sns.countplot(data1['is_paid'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Which courses has more lectures (Free or Paid)

# %%
data.groupby(['is_paid']).mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7908\700320043.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['is_paid']).mean()
#             course_id  num_subscribers  avg_rating  avg_rating_recent  \
# is_paid
# False    1.381390e+06     25457.089936    4.357310           4.369255
# True     1.463294e+06     29949.032011    4.468899           4.457657
#
#            rating  num_reviews  num_published_lectures  \
# is_paid
# False    4.369255  1350.559957               20.308351
# True     4.457657  4172.473452               81.490703
#
#          num_published_practice_tests  has_closed_caption  \
# is_paid
# False                        0.000000            0.905782
# True                         0.106958            0.940004
#
#          is_recently_published
# is_paid
# ...

# %% [markdown]
# ## Which courses have a higher number of subscribers Free or Paid?

# %% [markdown]
# ### Below this comparision can help you understand whether paid courses or free courses tend to attract more subscribers,which can impact pricing and revenue strategeies

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='is_paid',y ='num_subscribers',data=data)
plt.title(" paid vs free courses and subscribers")
plt.xlabel("paid vs free")
plt.ylabel("subscribers")
plt.show()

# %% [markdown]
# ## Which Level Has The Highest Number of Subscribers?

# %%
sns.barplot(x='instructional_level',y ='num_subscribers',data=data)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## Find the most popular course title

# %%
data[data['num_subscribers'].max()==data['num_subscribers']]['title']
# Out:
# 1625    2022 Complete Python Bootcamp From Zero to Her...
# Name: title, dtype: object

# %% [markdown]
# ## Which category Has The Highest Number of Subscribers

# %%
category_sub=data.groupby('category')['num_subscribers'].sum().sort_values(ascending=False)

# %%
plt.pie(category_sub.values,labels=category_sub.index,autopct='%0.1f%%',explode=None,startangle=180)
plt.title('Subscribers for each category')
plt.show()

# %% [markdown]
# ## Find Most Popular Course Title

# %%
data[data['num_subscribers'].max()==data['num_subscribers']]['title']
# Out:
# 1625    2022 Complete Python Bootcamp From Zero to Her...
# Name: title, dtype: object

# %% [markdown]
# ## Display 10 Most Popular Courses As Per Rating

# %%
top_5_courses=data.sort_values(by='num_reviews',ascending=False).head(5)

# %%
x=top_5_courses['title']
y=top_5_courses['num_reviews']
plt.ylabel('Course Title')
plt.xlabel('num_reviews')
plt.title('Most Popular Courses As reviews')
plt.barh(x,y)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Display 5 Most Popular Category As Per Number of Subscribers

# %%
top_5_categories=data.sort_values(by='num_subscribers',ascending=False)

# %%
x=top_5_categories['category']
y=top_5_categories['num_subscribers']
plt.ylabel('category')
plt.xlabel('num_subscribers')
plt.title('Most popular category as per num_subscriberrs')
plt.barh(x,y)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(18,3))
plt.xlabel('categories')
plt.ylabel('Number of Subscribers')
plt.title('Most Popular Categories As Per no. of Subscribers')
plt.scatter(data['category'],data['num_subscribers'])

# %% [markdown]
# ### Yes by above graph we can say that Development productivity categories are having maximum number of subscribers

# %% [markdown]
# ## Find The Course Which Is Having The Highest Number of Reviews

# %%
plt.figure(figsize=(10,4))
sns.barplot(x="category",y="num_reviews",data=data)
plt.xticks(rotation=60)
plt.show()

# %%
data.columns
# Out:
# Index(['course_id', 'title', 'is_paid', 'instructors', 'published_title',
#        'num_subscribers', 'avg_rating', 'avg_rating_recent', 'rating',
#        'num_reviews', 'num_published_lectures', 'num_published_practice_tests',
#        'has_closed_caption', 'created_at', 'instructional_level',
#        'published_at', 'is_recently_published', 'last_update_date',
#        'content_info', 'category'],
#       dtype='object')

# %% [markdown]
# ## Find Total Number of Courses Related To Python

# %%
course_related_to_python=data['title'].str.contains('Python',case=False).sum()
course_related_to_python
# Out:
# 131

# %%
python_top_10=data[data['title'].str.contains('Python',case=False)].sort_values(by='num_subscribers',ascending=False).head(10)

# %%
sns.barplot(x="num_subscribers",y="title",data=python_top_10)
y=python_top_10['num_subscribers']
plt.ylabel('Courses Related to Python')
plt.xlabel('subscribers')
plt.title("Most Popular Python Courses As Per num_subscribers")
plt.barh(x,y)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data['avg_rating'],bins=30,kde=True)
plt.title("distrubution avg rating")
plt.xlabel("ave rating")
plt.ylabel("frequency")
plt.show()

# %%
avg_rating_by_level=data.groupby("instructional_level")['avg_rating'].mean().reset_index()
plt.figure(figsize=(10,6))
sns.barplot(x="instructional_level",y="avg_rating",data=avg_rating_by_level)
plt.title("average rating by instructional level")
plt.xlabel("instructional level")
plt.ylabel("avg rating")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Below this comparision can help you understand if courses with higher rating to attract more subscribers,which could be valuable for course creation and marketers

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='avg_rating',y='num_subscribers',data=data)
plt.title("avg rating vs number of subscribers")
plt.xlabel("avg rating")
plt.ylabel("num of subscribers")
plt.show()

# %% [markdown]
# ### Below this compararion can help you identify whether highly rated courses receive more user reviews , which might indicate user satisfaction and engagement

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='avg_rating',y='num_reviews',data=data)
plt.title("avg rating vs number of reviews")
plt.xlabel("avg rating")
plt.ylabel("num of reviews")
plt.show()

# %% [markdown]
# ### Below this comparision can help you understand if courses at a particular instructional level tend to receive higher or lower ratings,which can inform course development strategies

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='instructional_level',y ='avg_rating',data=data)
plt.title("avg ratings by instructional level")
plt.xlabel("instuctional level")
plt.ylabel("avg rating")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='is_paid',y ='avg_rating',data=data)
plt.title("avg ratings for paid vs free")
plt.xlabel("paid vs free")
plt.ylabel("avg rating")
plt.show()

# %% [markdown]
# ### Below this comparision can help you understand whether paid courses or free courses tend to attract more subscribers,which can impact pricing and revenue strategeies

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='is_paid',y ='num_subscribers',data=data)
plt.title(" paid vs free courses and subscribers")
plt.xlabel("paid vs free")
plt.ylabel("subscribers")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='num_subscribers',y ='category',data=data.nlargest(15,'num_subscribers'))
plt.title("top 5 categories by number of subscribers")
plt.xlabel("number of subscriberrs")
plt.ylabel("category")
plt.show()

# %%
python_courses=data[data['category']=='software']
plt.figure(figsize=(12,6))
sns.barplot(x='num_subscribers',y ='title',data=python_courses.head(10))
plt.title("top 10 python courses")
plt.xlabel("number of subscriberrs")
plt.ylabel("course title")
plt.show()

# %%
highly_rating_courses=data.sort_values(by='rating',ascending=False).head(5)
plt.figure(figsize=(12,6))
sns.barplot(x='rating',y ='title',data=highly_rating_courses)
plt.title("top 5 highly rating courses")
plt.xlabel("rating")
plt.ylabel("course title")
plt.show()

# %% [markdown]
# ## Top 5 courses as per number of subsccribers

# %%
popular_courses=data.sort_values(by='num_subscribers',ascending=False).head(5)
plt.figure(figsize=(12,6))
sns.barplot(x='num_subscribers',y ='title',data=popular_courses)
plt.title("top 5 categories by number of subscribers")
plt.xlabel("number of subscriberrs")
plt.ylabel("course title")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='is_paid',y ='avg_rating',data=data)
plt.title("avg rating by paid/free courses")
plt.xlabel("paid/free")
plt.ylabel("avg  rating")
plt.xticks([0,1],['Free','Paid'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='avg_rating',y ='num_published_lectures',data=data)
plt.title("avg rating vs number of published lectures")
plt.xlabel("avg rating")
plt.ylabel("number of published lectures")
plt.show()

# %% [markdown]
# ## In which year the highest number of courses were posted?

# %%
year=data['year']=data['created_at'] .dt.year

# %%
data.head(10)
# Out:
#    course_id                                              title  is_paid  \
# 0     655608  Productivity and Time Management for the Overw...     True
# 1     591930  Become a SuperLearner® 2: Learn Speed Reading ...     True
# 2    1080376  Life Coaching Certificate Course (Beginner to ...     True
# 3    2108272      Time Management Mastery: Do More, Stress Less     True
# 4    1336872  Neuro-Linguistic Programming (NLP) Practitione...     True
# 5     941752                          Storytelling to Influence     True
# 6    1532040  Productivity Machine: Time Management & Produc...     True
# 7    1210442       Psychology of Diversity and Unconscious Bias     True
# 8     466736  Stress Management: 40+ easy ways to deal with ...     True
# 9    1432454  Effective Email Communication: Enhancing Your ...     True
#
#                                          instructors  \
# 0                                   ['Josh Paulsen']
# 1  ['Jonathan Levi', 'Lev Goldentouch', 'Anna Gol...
# ...

# %%
sns.countplot(x='year', data=data)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
data.groupby('year')['category'].value_counts()
# Out:
# year  category
# 2010  finance            1
# 2011  marketting         3
#       health_fitness     2
#       productivity       2
#       design             1
#                         ..
# 2021  design             4
#       development        2
#       business           1
#       lifestyle          1
# 2022  photography       10
# Name: category, Length: 128, dtype: int64

# %%
data['created_at']=data['created_at'].map(lambda x:x)

# %%
year=data['created_at'].value_counts()

# %%
x=year.index
y=year.values
plt.ylabel('Number of Courses')
plt.xlabel('year')
plt.title('Number of Courses posted per year')
plt.bar(x,y)
plt.grid(True)
plt.show()

# %%
sns.histplot(data['num_subscribers'],bins=20)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='Count'>

# %%
data
# Out:
#       course_id                                              title  is_paid  \
# 0        655608  Productivity and Time Management for the Overw...     True
# 1        591930  Become a SuperLearner® 2: Learn Speed Reading ...     True
# 2       1080376  Life Coaching Certificate Course (Beginner to ...     True
# 3       2108272      Time Management Mastery: Do More, Stress Less     True
# 4       1336872  Neuro-Linguistic Programming (NLP) Practitione...     True
# ...         ...                                                ...      ...
# 6146    2433278  Computer Basics - Windows 7/10 - Desktop IT Su...     True
# 6147    1638736              Understanding and Troubleshooting SIP     True
# 6148    1386242              Hands-on Penetration Testing Labs 1.0     True
# 6149    2773144                  The Complete C++ Developer Course     True
# 6150    3438306                Python NumPy For Absolute Beginners    False
#
# ...

# %%
data
# Out:
#       course_id                                              title  is_paid  \
# 0        655608  Productivity and Time Management for the Overw...     True
# 1        591930  Become a SuperLearner® 2: Learn Speed Reading ...     True
# 2       1080376  Life Coaching Certificate Course (Beginner to ...     True
# 3       2108272      Time Management Mastery: Do More, Stress Less     True
# 4       1336872  Neuro-Linguistic Programming (NLP) Practitione...     True
# ...         ...                                                ...      ...
# 6146    2433278  Computer Basics - Windows 7/10 - Desktop IT Su...     True
# 6147    1638736              Understanding and Troubleshooting SIP     True
# 6148    1386242              Hands-on Penetration Testing Labs 1.0     True
# 6149    2773144                  The Complete C++ Developer Course     True
# 6150    3438306                Python NumPy For Absolute Beginners    False
#
# ...
